# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import NearestNeighbors

items = pd.read_csv("items.csv", sep="|")
print(items.shape)
items.sample(10)
# Out:
# (78030, 6)
#        itemID                                            title  \
# 41533   60966                                       Adlerjunge
# 25749   63906                                    Miles Between
# 37338   55908                    Primavera Libro Para Colorear
# 76075   68658                                           Broken
# 7810    48688                                           Armada
# 22682   42360                                     Displacement
# 21850   13263                                   Justus Schneck
# 66130   33020                                     Days to Hide
# 4714    72863  The Extraordinary Adventures of Sherlock Holmes
# 32389   22766                                One Creepy Street
#
#                            author                 publisher main topic  \
# 41533              Rodney Bennett  Freies Geistesleben GmbH         YF
# 25749              Mary E Pearson     St. Martins Press-3PL        YFB
# 37338                El Blokehead                     Blurb        YFB
# 76075  Alyxandra Harvey-Fitzhenry           Tradewind Books        YFB
# 7810                 Ernest Cline               FISCHER TOR        FBA
# 22682                 Kiku Hughes       Roaring Brook Press       XADC
# 21850           Sabine Wittemeier                   NOVA MD        YBL
# 66130             Stephanie Flynn     Small Fish Publishing        FRU
# 4714           Arthur Conan Doyle        Vintage Publishing       YFCF
# 32389                  Lee Jordan        Black Rose Writing        YFD
#
#                                            subtopics
# 41533                                          [5AN]
# 25749                                           [YX]
# 37338                                             []
# 76075                                             []
# 7810   [5LF,1KB,FBA,FLP,FLQ,FLR,FLS,FLU,FYT,FYW,YFG]
# 22682                                           [YF]
# 21850                                      [FV,G,WN]
# 66130                                             []
# 4714                                           [YFA]
# 32389                                             []

# %%
items = items[["itemID", "title", "author"]]
items.head()
# Out:
#    itemID                                      title              author
# 0   21310             Princess Poppy: The Big Mix Up  Janey Louise Jones
# 1   73018             Einfach zeichnen! Step by Step       Wiebke Krabbe
# 2   19194                                Red Queen 1    Victoria Aveyard
# 3   40250         Meine Kindergarten-Freunde (Pirat)                 NaN
# 4   46107  Mein großes Schablonen-Buch - Wilde Tiere   Elizabeth Golding

# %%
transactions = pd.read_csv("transactions.csv", sep="|")
print("Shape: ", transactions.shape,"Filtered shape:", transactions[(transactions['order'] > 0)].shape, sep="\n")
transactions.sample(10)
# Out:
# Shape:
# (365143, 5)
# Filtered shape:
# (16906, 5)
#         sessionID  itemID  click  basket  order
# 227065     173601   43101      1       0      0
# 219318     167623   49234      0       0      1
# 35591       27025   69619      1       0      0
# 253163     193826    8084      1       0      0
# 280612     214754    3083      1       0      0
# 324548     248463   68641      1       0      0
# 317625     243119   25641      1       0      0
# 348727     266871    7294      1       0      0
# 123502      94324   13748      3       0      0
# 240765     184200   16698      1       0      0

# %%
merged = pd.merge(items, transactions, on="itemID")
print("Merged shape:", merged.shape, "After filter:",  merged[(merged['order'] > 0)].shape, sep="\n")
merged = merged[(merged['order'] > 0)]
print("Null values:","\n",merged.isnull().sum())
merged.dropna(inplace=True)
print("Merged shape:", merged.shape, "\nMerged Dataset:")
merged.sample(10)
# Out:
# Merged shape:
# (365143, 7)
# After filter:
# (16906, 7)
# Null values:
#  itemID          0
# title           0
# author       1249
# sessionID       0
# click           0
# basket          0
# order           0
# dtype: int64
# Merged shape: (15657, 7)
# Merged Dataset:
#         itemID                                              title  \
# 299926   56731        Mein Anziehpuppen-Stickerbuch: Meine Katzen
# 340570   15651                                Leah on the Offbeat
# 146322   12016  Das Buch der gelöschten Wörter - Die letzten Z...
# 6445     11525                                    Zeit des Sturms
# 313328   56245                       Nähen lernen auf Papierbögen
# 312843   33869                  Miles & Niles - Jetzt wird's wild
# 18497    62556                      Level 4. Die Stadt der Kinder
# 12785    14207                                  Der letzte Wunsch
# 169083   34815                Als Hitler das rosa Kaninchen stahl
# 332115   38348                                     All Eyes on Us
#
#                         author  sessionID  click  basket  order
# 299926             Lucy Bowman      16405      0       0      1
# 340570        Becky Albertalli     236707      0       0      1
# 146322          Mary E. Garner      55623      0       0      1
# 6445         Andrzej Sapkowski     111623      0       0      1
# 313328           Anika Weimert     208718      0       0      1
# 312843  Jory John, Mac Barnett      85478      0       0      1
# 18497         Andreas Schlüter     101430      0       0      1
# 12785        Andrzej Sapkowski     253480      0       0      1
# 169083             Judith Kerr     209523      0       0      1
# 332115               Kit Frick      93451      0       0      1

# %%
merged_pivot = merged.pivot_table(columns="sessionID", index="title", values="order")
print("Pivot shape:", merged_pivot.shape)
merged_pivot
# Out:
# Pivot shape: (4625, 12379)
# sessionID                                           15      54      60      \
# title
# #Basteln for Future                                    NaN     NaN     NaN
# #Wir bleiben zuhause Kindermitmachbuch                 NaN     NaN     NaN
# #selbstschuld - Was heißt schon privat                 NaN     NaN     NaN
# ... und dann kam Joselle                               NaN     NaN     NaN
# 1, 2, 3, 4 Lieblingstier                               NaN     NaN     NaN
# ...                                                    ...     ...     ...
# tiptoi® Die Welt der Musik                             NaN     NaN     NaN
# tiptoi® Tiere im Garten                                NaN     NaN     NaN
# tiptoi® Unterwegs mit der Feuerwehr                    NaN     NaN     NaN
# verliebt, versohlt, versklavt - wenn Strenge no...     NaN     NaN     NaN
# Ängstlich, wütend, fröhlich sein                       NaN     NaN     NaN
#
# sessionID                                           90      104     128     \
# title
# #Basteln for Future                                    NaN     NaN     NaN
# #Wir bleiben zuhause Kindermitmachbuch                 NaN     NaN     NaN
# #selbstschuld - Was heißt schon privat                 NaN     NaN     NaN
# ... und dann kam Joselle                               NaN     NaN     NaN
# 1, 2, 3, 4 Lieblingstier                               NaN     NaN     NaN
# ...                                                    ...     ...     ...
# tiptoi® Die Welt der Musik                             NaN     NaN     NaN
# tiptoi® Tiere im Garten                                NaN     NaN     NaN
# tiptoi® Unterwegs mit der Feuerwehr                    NaN     NaN     NaN
# verliebt, versohlt, versklavt - wenn Strenge no...     NaN     NaN     NaN
# Ängstlich, wütend, fröhlich sein                       NaN     NaN     NaN
#
# sessionID                                           153     177     180     \
# title
# #Basteln for Future                                    NaN     NaN     NaN
# #Wir bleiben zuhause Kindermitmachbuch                 NaN     NaN     NaN
# #selbstschuld - Was heißt schon privat                 NaN     NaN     NaN
# ... und dann kam Joselle                               NaN     NaN     NaN
# 1, 2, 3, 4 Lieblingstier                               NaN     NaN     NaN
# ...                                                    ...     ...     ...
# tiptoi® Die Welt der Musik                             NaN     NaN     NaN
# tiptoi® Tiere im Garten                                NaN     NaN     NaN
# tiptoi® Unterwegs mit der Feuerwehr                    NaN     NaN     NaN
# verliebt, versohlt, versklavt - wenn Strenge no...     NaN     NaN     NaN
# Ängstlich, wütend, fröhlich sein                       NaN     NaN     NaN
#
# sessionID                                           194     ...  279101  \
# title                                                       ...
# #Basteln for Future                                    NaN  ...     NaN
# #Wir bleiben zuhause Kindermitmachbuch                 NaN  ...     NaN
# #selbstschuld - Was heißt schon privat                 NaN  ...     NaN
# ... und dann kam Joselle                               NaN  ...     NaN
# 1, 2, 3, 4 Lieblingstier                               NaN  ...     NaN
# ...                                                    ...  ...     ...
# tiptoi® Die Welt der Musik                             NaN  ...     NaN
# tiptoi® Tiere im Garten                                NaN  ...     NaN
# tiptoi® Unterwegs mit der Feuerwehr                    NaN  ...     NaN
# verliebt, versohlt, versklavt - wenn Strenge no...     NaN  ...     NaN
# Ängstlich, wütend, fröhlich sein                       NaN  ...     NaN
#
# sessionID                                           279104  279116  279154  \
# title
# #Basteln for Future                                    NaN     NaN     NaN
# #Wir bleiben zuhause Kindermitmachbuch                 NaN     NaN     NaN
# #selbstschuld - Was heißt schon privat                 NaN     NaN     NaN
# ... und dann kam Joselle                               NaN     NaN     NaN
# 1, 2, 3, 4 Lieblingstier                               NaN     NaN     NaN
# ...                                                    ...     ...     ...
# tiptoi® Die Welt der Musik                             NaN     NaN     NaN
# tiptoi® Tiere im Garten                                NaN     NaN     NaN
# tiptoi® Unterwegs mit der Feuerwehr                    NaN     NaN     NaN
# verliebt, versohlt, versklavt - wenn Strenge no...     NaN     NaN     NaN
# Ängstlich, wütend, fröhlich sein                       NaN     NaN     NaN
#
# sessionID                                           279181  279199  279200  \
# title
# #Basteln for Future                                    NaN     NaN     NaN
# #Wir bleiben zuhause Kindermitmachbuch                 NaN     NaN     NaN
# #selbstschuld - Was heißt schon privat                 NaN     NaN     NaN
# ... und dann kam Joselle                               NaN     NaN     NaN
# 1, 2, 3, 4 Lieblingstier                               NaN     NaN     NaN
# ...                                                    ...     ...     ...
# tiptoi® Die Welt der Musik                             NaN     NaN     NaN
# tiptoi® Tiere im Garten                                NaN     NaN     NaN
# tiptoi® Unterwegs mit der Feuerwehr                    NaN     NaN     NaN
# verliebt, versohlt, versklavt - wenn Strenge no...     NaN     NaN     NaN
# Ängstlich, wütend, fröhlich sein                       NaN     NaN     NaN
#
# sessionID                                           279238  279285  279309
# title
# #Basteln for Future                                    NaN     NaN     NaN
# #Wir bleiben zuhause Kindermitmachbuch                 NaN     NaN     NaN
# #selbstschuld - Was heißt schon privat                 NaN     NaN     NaN
# ... und dann kam Joselle                               NaN     NaN     NaN
# 1, 2, 3, 4 Lieblingstier                               NaN     NaN     NaN
# ...                                                    ...     ...     ...
# tiptoi® Die Welt der Musik                             NaN     NaN     NaN
# tiptoi® Tiere im Garten                                NaN     NaN     NaN
# tiptoi® Unterwegs mit der Feuerwehr                    NaN     NaN     NaN
# verliebt, versohlt, versklavt - wenn Strenge no...     NaN     NaN     NaN
# Ängstlich, wütend, fröhlich sein                       NaN     NaN     NaN
#
# [4625 rows x 12379 columns]

# %%
merged_pivot.fillna(0, inplace=True)
merged_pivot.sample(10)
# Out:
# sessionID                                     15      54      60      90      \
# title
# Kernstaub                                        0.0     0.0     0.0     0.0
# 17, Das dritte Buch der Erinnerung               0.0     0.0     0.0     0.0
# World of Warcraft: Der Untergang der Aspekte     0.0     0.0     0.0     0.0
# Winston - Kater Undercover                       0.0     0.0     0.0     0.0
# Tintenwelt-Schuber                               0.0     0.0     0.0     0.0
# Bartimäus 03. Die Pforte des Magiers             0.0     0.0     0.0     0.0
# Honigkuckuckskinder                              0.0     0.0     0.0     0.0
#
# sessionID                                     279309
# title
# Kernstaub                                        0.0
# 17, Das dritte Buch der Erinnerung               0.0
# Perfect Twin - Der Aufbruch                      0.0
# Rat der Neun - Gegen das Schicksal               0.0
# Der Sommer, als ich schön wurde                  0.0
# World of Warcraft: Der Untergang der Aspekte     0.0
# Winston - Kater Undercover                       0.0
# Tintenwelt-Schuber                               0.0
# Bartimäus 03. Die Pforte des Magiers             0.0
# Honigkuckuckskinder                              0.0
#
# [10 rows x 12379 columns]

# %% [markdown]
# #### Model oluşturmadan, item-item collaborative filtering kullanarak ve birden fazla transaction'a sahip id'leri kullanarak deneyelim:

# %%
def update_pivot(df):
    for i in df.index:
        non_zero_values = df.loc[i, df.columns != 0]
        mean = non_zero_values.mean()
        for j in df.columns:
            if df.loc[i, j] != 0:
                df.loc[i, j] -= mean
    return df

def cosine(df):
    cosine_similarity_matrix = cosine_similarity(df)
    print("Cosine Matrix shape:", cosine_similarity_matrix.shape)
    return cosine_similarity_matrix

def recommend_w_similarities(book_title, similarity, pivot_df, k):
    try:
        # Kitap indeksi bulmak için
        book_index = pivot_df.index.get_loc(book_title)

        # Kitaba en yakın komşuların indeksleri ve benzerlik skorları
        nearest_indices = np.argsort(similarity[book_index]) # küçükten büyüğe sıralı
        nearest_indices = nearest_indices[::-1][1:k] # en yakın k indeksi bulmak için önce listeyi terse çevirip sonra ilk k değeri almak lazım
        similarity_scores = similarity[book_index, nearest_indices] # ilgili kitaba en yakın indislerin cosine similarity değerleri

        # Öneri ve Benzerlik Skorlarını Oluşturma
        recommendations = pivot_df.index[nearest_indices]
        recommendation_scores = list(zip(recommendations, similarity_scores))

        print(f"Kitap: {book_title}")
        print("Önerilen Kitaplar ve Benzerlik Skorları:")
        for i, (book, score) in enumerate(recommendation_scores):
            print(f"{i + 1}. {book} - Benzerlik Skoru: {score:.2f}")

        return recommendations
    except KeyError:
        print(f"'{book_title}' adında bir kitap bulunamadı.")
        return []

    
def steps(title,threshold, k, control = 0):
    # Verileri yükle
    items = pd.read_csv("items.csv", sep="|")
    items = items[["itemID", "title", "author"]]

    transactions = pd.read_csv("transactions.csv", sep="|")
    session_counts = transactions["sessionID"].value_counts()
    valids = session_counts[session_counts >= threshold].index
    filtered_transactions = transactions[transactions["sessionID"].isin(valids)]

    merged = pd.merge(items, filtered_transactions, on="itemID")
    merged = merged[(merged['order'] > 0)] # sadece satın alımın olduğu session'ları dikkate almak için
    merged.dropna(inplace=True)
    print("Merged Dataset shape:", merged.shape)
    
    merged_pivot = merged.pivot_table(columns="sessionID", index="title", values="order")
    print("Pivot shape:", merged_pivot.shape)
    merged_pivot.fillna(0, inplace=True)
    result = update_pivot(merged_pivot.copy())
    print("Result shape:", result.shape)

    if control != 0:
        print(result.sample(10))

    similarities = cosine(result.copy())
    recommend_w_similarities(title, similarities, result, k=k+1)

    return result, merged, merged_pivot

title = "Harry Potter 1 und der Stein der Weisen" 
# Harry Potter 2 and the Chamber of Secrets
# Die letzte Königin - Das Feuer erwacht
# Mortal Instruments 01. City of Bones
# Warrior Cats Staffel 3/04. Die Macht der drei. Zeit der Dunkelheit
# Sternenschweif 25: Freundschaftszauber
# The Mortal Instruments 1-6 Slipcase

result, merged, merged_pivot = steps(title, threshold = 5, k = 5)
# Out:
# Merged Dataset shape: (1067, 7)
# Pivot shape: (764, 281)
# Result shape: (764, 281)
# Cosine Matrix shape: (764, 764)
# Kitap: Harry Potter 1 und der Stein der Weisen
# Önerilen Kitaplar ve Benzerlik Skorları:
# 1. Harry Potter 2 und die Kammer des Schreckens - Benzerlik Skoru: 0.87
# 2. Harry Potter 3 und der Gefangene von Askaban - Benzerlik Skoru: 0.82
# 3. Harry Potter 6 und der Halbblutprinz - Benzerlik Skoru: 0.71
# 4. Harry Potter 4 und der Feuerkelch. Taschenbuch - Benzerlik Skoru: 0.67
# 5. Harry Potter 5 und der Orden des Phönix - Benzerlik Skoru: 0.62

# %%
def search(result, str):
    # verilen string ifadesini içeren indeksleri bulmak için
    contains = result.index.str.contains(str, case=False)

    # O indeks değerlerine göre satırları bulmak için
    rows = result[contains]

    print(f"{str} içeren satırlar:")
    print(rows)
    
search(result, "Harry Potter")
# Out:
# Harry Potter içeren satırlar:
# sessionID                                           824     2011    2446    \
# title
# Harry Potter 1 und der Stein der Weisen                0.0     0.0     0.0
# Harry Potter 2 and the Chamber of Secrets              0.0     0.0     0.0
# Harry Potter 2 und die Kammer des Schreckens           0.0     0.0     0.0
# Harry Potter 3 and the Prisoner of Azkaban             0.0     0.0     0.0
# Harry Potter 3 und der Gefangene von Askaban           0.0     0.0     0.0
# Harry Potter 4 and the Goblet of Fire                  0.0     0.0     0.0
# Harry Potter 4 und der Feuerkelch. Taschenbuch         0.0     0.0     0.0
# Harry Potter 5 and the Order of the Phoenix            0.0     0.0     0.0
# Harry Potter 5 und der Orden des Phönix                0.0     0.0     0.0
# Harry Potter 6 and the Half-Blood Prince               0.0     0.0     0.0
# Harry Potter 6 und der Halbblutprinz                   0.0     0.0     0.0
# Harry Potter 7 and the Deathly Hallows                 0.0     0.0     0.0
# Harry Potter 7 und die Heiligtümer des Todes           0.0     0.0     0.0
# Harry Potter und das verwunschene Kind. Teil ei...     0.0     0.0     0.0
# LEGO® Harry Potter(TM) Das magische Lexikon            0.0     0.0     0.0
#
# sessionID                                           3893    4307    4518    \
# title
# Harry Potter 1 und der Stein der Weisen                0.0     0.0     0.0
# Harry Potter 2 and the Chamber of Secrets              0.0     0.0     0.0
# Harry Potter 2 und die Kammer des Schreckens           0.0     0.0     0.0
# Harry Potter 3 and the Prisoner of Azkaban             0.0     0.0     0.0
# Harry Potter 3 und der Gefangene von Askaban           0.0     0.0     0.0
# Harry Potter 4 and the Goblet of Fire                  0.0     0.0     0.0
# Saeculum                                               0.0     0.0     0.0
# Goldene Flammen                                        0.0     0.0     0.0
# Die Wilden Hühner auf Klassenfahrt                     0.0     0.0     0.0
# Star Wars(TM) - Darth Bane                             0.0     0.0     0.0
# Mein Wisch-und-weg-Buch Schulstart: Ich schreib...     0.0     0.0     0.0
# Black Dagger 24. Königsblut                            0.0     0.0     0.0
# Der Triumph der Zwerge                                 0.0     0.0     0.0
# Rätselblock ab 8 Jahre, Band 1, A5-Block               0.0     0.0     0.0
# Cress                                                  0.0     0.0     0.0
# Der Zeitdieb                                           0.0     0.0     0.0
# Die Chaosschwestern sind unschlagbar                   0.0     0.0     0.0
# Gregs Tagebuch 02. Gibt's Probleme?                    0.0     0.0     0.0
# Kunterbunte Rätsel zum Lesenlernen (2. Lesestufe)      0.0     0.0     0.0
# Charlie und die Schokoladenfabrik                      0.0     0.0     0.0
#
# sessionID                                           6058    ...    268902  \
# title                                                       ...
# Mein Anziehpuppen-Stickerbuch: Drei Freundinnen...     0.0  ...  0.000000
# Die staubsaugende Schreckschraube                      0.0  ...  0.000000
# Der kleine Vampir                                      0.0  ...  0.000000
# Gregs Tagebuch 10 - So ein Mist!                       0.0  ...  0.000000
# Full Disclosure                                        0.0  ...  0.000000
# Biss zum Ende der Nacht                                0.0  ...  0.000000
# Saeculum                                               0.0  ...  0.000000
# Goldene Flammen                                        0.0  ...  0.000000
# Die Wilden Hühner auf Klassenfahrt                     0.0  ...  0.000000
# Star Wars(TM) - Darth Bane                             0.0  ...  0.000000
# Mein Wisch-und-weg-Buch Schulstart: Ich schreib...     0.0  ...  0.000000
# Black Dagger 24. Königsblut                            0.0  ...  0.000000
# Der Triumph der Zwerge                                 0.0  ...  0.000000
# Rätselblock ab 8 Jahre, Band 1, A5-Block               0.0  ...  0.982206
# Cress                                                  0.0  ...  0.000000
# Der Zeitdieb                                           0.0  ...  0.000000
# Die Chaosschwestern sind unschlagbar                   0.0  ...  0.000000
# Gregs Tagebuch 02. Gibt's Probleme?                    0.0  ...  0.000000
# Kunterbunte Rätsel zum Lesenlernen (2. Lesestufe)      0.0  ...  0.000000
# Charlie und die Schokoladenfabrik                      0.0  ...  0.000000
#
# sessionID                                           270350    271816  273431  \
# title
# Mein Anziehpuppen-Stickerbuch: Drei Freundinnen...     0.0  0.000000     0.0
# Die staubsaugende Schreckschraube                      0.0  0.000000     0.0
# Der kleine Vampir                                      0.0  0.000000     0.0
# Gregs Tagebuch 10 - So ein Mist!                       0.0  0.000000     0.0
# Full Disclosure                                        0.0  0.000000     0.0
# Biss zum Ende der Nacht                                0.0  0.000000     0.0
# Saeculum                                               0.0  0.000000     0.0
# Goldene Flammen                                        0.0  0.000000     0.0
# Die Wilden Hühner auf Klassenfahrt                     0.0  0.000000     0.0
# Star Wars(TM) - Darth Bane                             0.0  0.996441     0.0
# Mein Wisch-und-weg-Buch Schulstart: Ich schreib...     0.0  0.000000     0.0
# Black Dagger 24. Königsblut                            0.0  0.000000     0.0
# Der Triumph der Zwerge                                 0.0  0.000000     0.0
